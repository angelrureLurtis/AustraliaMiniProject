# %% [markdown]
# ### Requirements

# %% [markdown]
# Build a Notebook for Yi Peng with the following requisites:
#
#
#
# Yi Peng can insert an address and search area range (int)
#
# The notebook should:
#
# 1. Pull all of the national indicators
#
# 2. Pull all of the local indicators with the tag "any" that are of a granularity finder than national and are within 200 miles of the address
#
# 3. Pull all of the "retail" indicators that DO NOT have an asset ID associated with them

# %% [markdown]
# # Calls

# %%
import queries
import pandas as pd

# %%
_ = queries.search_by_distance('Sydney', 10, 'miles', False, 'Any', all_levels=True ,parse_to_pandas=True)
# Out:
# Using level API

# %%
pd.DataFrame(_).search_key.unique()
# Out:
# array(['Australia AU-QLD ABS NET_OVERSEAS_MIGRATION persons',
#        'Australia FOCUS 90_BANK_BILL %',
#        'Australia FOCUS ACCOUNT_BALANCE % of GDP',
#        'Australia FOCUS NGDP ann %', 'Australia FOCUS REXPORT ann %',
#        'Australia FOCUS FISCAL_BALANCE % of GDP',
#        'Australia FOCUS CPI ann %',
#        'Australia FOCUS MERCH_TRADE_BALANCE USDb',
#        'Australia FOCUS MONEY ann %',
#        'Australia FOCUS STOCK_MARKET ann %',
#        'Australia AU-NSW ABS POPULATION persons',
#        'Australia AU-NSW ABS NET_INWARD_MIGRATION persons',
#        'Australia AU-NSW ABS NET_OVERSEAS_MIGRATION persons',
#        'Australia AU-VIC ABS NET_OVERSEAS_MIGRATION persons',
#        'Australia AU-NT ABS NET_OVERSEAS_MIGRATION persons',
#        'Australia FOCUS TBOND %', 'Australia FOCUS GDP ann %',
#        'Australia FOCUS FIXED_INVEST ann %',
#        'Australia FOCUS RIMPORT ann %',
#        'Australia FOCUS POPULATION persons_m',
# ...

# %% [markdown]
# ### 1. All national indicators

# %%
queries.return_all_national_indicators()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f285624320cf> in <module>
# ----> 1 queries.return_all_national_indicators()
#
# ~/Dropbox/Lurtis/Australia_miniproject/AustraliaMiniProject/geolocalization/queries.py in return_all_national_indicators(location, parse_json)
#      95
# ...

# %% [markdown]
# ### 2. Search by tag and radius

# %%
# Change the first and second parameter (the location and  distance) 
# and the last one (the tag, which is currently using the requested one in the specifications (Any).)

_ = queries.search_by_distance('Sydney', 10, 'miles', False, 'Any', indicator='POPULATION')

# %%
_.keys()

# %% [markdown]
# ### 3. Search by tag and radius and filtering by not having assets

# %%
# The fourth parameters, (which is set to False) is whether to use use the indicators with assets.

queries.search_by_distance('Sydney', 200, 'km', False, 'Retail')

# %%
# The fourth parameters, (which is set to False) is whether to use use the indicators with assets.

queries.search_by_distance('Perth', 200, 'km', True, 'Retail')

# %%
data = {
        'location_name': 'Sydney',
        'distance': 100000000,
        'distance_type': 'km',
        'folder_name':'Any',
        'include_indicators_with_assets': False
    }

# %%
queries.search_by_distance('Sydney', 100, 'miles', True, 'Retail')

# %%
import requests

# %%
data = {
        'location_name': 'Sydney',
        'distance': 100000000,
        'distance_type': 'km',
        'folder_name':'Any',
        'include_indicators_with_assets': False,
    }

url = 'http://ec2-13-229-144-6.ap-southeast-1.compute.amazonaws.com'
path = 'ui_geosearch_query'
port = '5000'
    
request = requests.post(f'{url}:{port}/{path}', json=data)

# %%
request.json()

# %%
_ = queries.search_by_distance('Sydney', 30, 'miles', False, 'Any', parse_to_pandas=True)

# %%
pd.DataFrame(_)
# Out:
#     actual_value country        date  \
# 0    7.40403e+06     AUS  2013-12-31
# 1    7.50835e+06     AUS  2014-12-31
# 2    7.61617e+06     AUS  2015-12-31
# 3    7.73286e+06     AUS  2016-12-31
# 4    7.86794e+06     AUS  2017-12-31
# 5    7.98824e+06     AUS  2018-12-31
# 6                    AUS  2019-12-31
# 7                    AUS  2020-12-31
# 8                    AUS  2021-12-31
# 9                    AUS  2022-12-31
# 10                   AUS  2023-12-31
# 11                   AUS  2024-12-31
# 12                   AUS  2025-12-31
# 13                   AUS  2026-12-31
# 14                   AUS  2027-12-31
# 15                   AUS  2028-12-31
# 16                   AUS  2029-12-31
# 17        -15161     AUS  2017-12-31
# 18        -21672     AUS  2018-12-31
# 19         3.144     AUS  2016-01-01
# 20                   AUS  2021-01-01
# 21                   AUS  2026-01-01
# 22                   AUS  2031-01-01
# 23                   AUS  2036-01-01
# ...

# %%
[x.split(' ')[2:5] for x in __.keys()]

# %%
import requests

# %%
q  = queries._retrieve_query_settings(())
url = q['url']
port = q['port']
path = q['path']

# %%
data = {
    'location_name': 'Sydney',
    'distance': 100,
    'distance_type': 'miles'.lower(),
    'folder_name':'Retail',
    'include_indicators_with_assets': True
}


request = requests.post(f'{url}:{port}/{path}', json=data)
