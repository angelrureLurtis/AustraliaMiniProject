# %% [markdown]
# # Exploring indicators

# %% [markdown]
# This notebook explores the existence of Yi Peng's indicators in ABS and id_population sources.
# Then we will try to segment by type and see if we can extrapolate the data.

# %% [markdown]
# ## Function definitions and django manage

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

import os
import pandas as pd

os.chdir('../deciml_django/')

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'deciml.settings')

from deciml.apps.db.models import *
from deciml.apps.common.utils import get_actuals

# %%
def sources_that_contain_indicator(indicator):
    """
    indicator should be the minimum you want to find. indicator='Hoc' would
    match both Hockey and ChOcOlate.
    """
    df = pd.DataFrame(Indicator.objects.filter(indicator_info__name__icontains=indicator)\
                               .values('indicator_info__id',
                                       'indicator_info__name', 
                                       'indicator_info__description',
                                       'source__id'))
    
    df = df.drop_duplicates()
    diff_sources = df.source__id.unique()
    diff_ind = df.indicator_info__name.unique()
    
    print('* Different indicators found ({ndi}): {di}'.format(ndi=len(diff_ind), di=diff_ind))
    print('* Different sources found ({nds}): {ds}'.format(nds=len(diff_sources), ds=diff_sources))
    return df

# %%
def indicators_from_source(source):
    df = pd.DataFrame(Indicator.objects.filter(source__id=source)\
                               .distinct('indicator_info__name')\
                               .values('indicator_info__name', 
                                       'indicator_info__description'))
    return df

# %%
def values_by_indicator_and_source(source, indicator):

    df = pd.DataFrame(

           Actual.objects.filter(indicator__source__id=source,
                                 indicator__indicator_info__name=indicator)\
                 .values('date', 'value', 'indicator__location__name')
    )
    
    return df

# %% [markdown]
# #### Target indicators

# %% [markdown]
# - [x] state population (ID_POPUL:Population, ABS:Population)
#     * Poor time depth
# - [x] city population (ID_POPUL:Population --> Description is wrong)
# - [x] GDP (ABS:Gross domestic product)
#     * Whole state
# - [x] household income (ABS:Gross Disposable Income)
#     * Whole state
# - [ ] household indebtedness

# %% [markdown]
# #### Extra indicators

# %% [markdown]
# - [X] Unemployment Tate (ABS:unemployment rate)

# %% [markdown]
# ## Exploring indicators and sources

# %% [markdown]
# We want to check if Yi Peng's indicators are available in several sources. Then we will check which sources have data about the vacancy/occupation, the cap_rate/yield or the specialty sales.

# %% [markdown]
# ### Indicators from ID_POPUL and ABS

# %%
indicators_from_source('ID_POPUL')
# Out:
#                   indicator_info__name          indicator_info__description
# 0               Average household size         Average people per household
# 1              Dwelling occupancy rate     Percentage of dwelling occupancy
# 2                            Dwellings                  Number of dwellings
# 3                           Households                 Number of households
# 4                           Population  Number of persons living in a state
# 5  Population in non private dwellings  Population in non private dwellings

# %%
indicators_from_source('ABS')
# Out:
#                     indicator_info__name  \
# 0                      building approved
# 1                         business gross
# 2                        business income
# 3                       business lending
# 4                   Female to Male ratio
# 5                Gross Disposable Income
# 6                 Gross domestic product
# 7                    Gross State Product
# 8                 Household Size Average
# 9                 Net Overseas Migration
# 10                  New inward migration
# 11     New residential building approved
# 12       New residential building values
# 13                            Population
# 14              Population Born Overseas
# 15                    Population Density
# 16   Residential building work commenced
# 17  Residential building work done value
# 18                       Retail Turnover
# 19                     unemployment rate
# 20                 white collar employed
#
#                           indicator_info__description
# 0    total value of approved service sector buildings
# 1            gross value of service sector businesses
# 2   total value of income by service sector busine...
# 3          value lending to service sector businesses
# 46  1986-12-01   675016.0                 Australia
# 47  1985-12-01   660998.0                 Australia
# 48  1984-12-01   629293.0                 Australia
# 49  1983-12-01   589893.0                 Australia
# 50  1982-12-01   593765.0                 Australia
# 51  1981-12-01   592577.0                 Australia
# 52  1980-12-01   569067.0                 Australia
# 53  1979-12-01   553222.0                 Australia
# 54  1978-12-01   531515.0                 Australia
# 55  1963-12-01   290031.0                 Australia
# 56  1962-12-01   272960.0                 Australia
# 57  1961-12-01   258960.0                 Australia
# 58  1960-12-01   258865.0                 Australia
# 59  1959-12-01   125539.0                 Australia

# %%
# Gross Disposable Income by state??
values_by_indicator_and_source('ABS', 'Gross Disposable Income')
# Out:
#           date      value indicator__location__name
# 0   2002-06-01  1137030.0                 Australia
# 1   2001-06-01  1062416.0                 Australia
# 2   2000-06-01   984253.0                 Australia
# 3   1999-06-01   925488.0                 Australia
# 4   1998-06-01   883062.0                 Australia
# 5   1997-06-01   849097.0                 Australia
# 6   1996-06-01   803289.0                 Australia
# 7   1995-06-01   752868.0                 Australia
# 8   1994-06-01   708298.0                 Australia
# 9   1993-06-01   679594.0                 Australia
# 10  1992-06-01   658893.0                 Australia
# 11  1991-06-01   649434.0                 Australia
# 12  1990-06-01   624659.0                 Australia
# 13  2018-06-01  2760313.0                 Australia
# 14  2017-06-01  2674779.0                 Australia
# 15  2016-06-01  2612899.0                 Australia
# 16  2015-06-01  2552845.0                 Australia
# 17  2014-06-01  2446949.0                 Australia
# 18  2013-06-01  2336308.0                 Australia
# 19  2012-06-01  2275718.0                 Australia
# 20  2011-06-01  2147729.0                 Australia
# 21  2010-06-01  1985840.0                 Australia
# 22  2009-06-01  1923312.0                 Australia
# 23  2008-06-01  1774775.0                 Australia
# 24  2007-06-01  1610144.0                 Australia
# 25  2006-06-01  1470577.0                 Australia
# 26  2005-06-01  1385358.0                 Australia
# 27  2004-06-01  1279892.0                 Australia
# 28  2003-06-01  1180891.0                 Australia

# %%
# Unemployment rate by state
values_by_indicator_and_source('ABS', 'unemployment rate')
# Out:
#             date     value    indicator__location__name
# 0     2014-12-01  6.100007                    Australia
# 1     2014-11-01  6.297957                    Australia
# 2     2014-10-01  6.381043                    Australia
# 3     2014-09-01  6.225912                    Australia
# 4     2014-08-01  6.091151                    Australia
# ...          ...       ...                          ...
# 3460  1979-10-01  7.868502  Western Australia Australia
# 3461  1979-09-01  7.216421  Western Australia Australia
# 3462  1979-08-01  7.297816  Western Australia Australia
# 3463  1979-07-01  7.573855  Western Australia Australia
# 3464  1979-06-01  6.882589  Western Australia Australia
#
# [3465 rows x 3 columns]

# %%
values_by_indicator_and_source('ABS', 'unemployment rate').indicator__location__name.unique()
# Out:
# array(['Australia', 'New South Wales Australia', 'Queensland Australia',
#        'South Australia Australia', 'Tasmania Australia',
#        'Victoria Australia', 'Western Australia Australia'], dtype=object)

# %% [markdown]
# ### Who has vacancy data (Or occupation)?

# %%
_ = sources_that_contain_indicator('vac')
# Out:
# * Different indicators found (17): ['Total Vacancy Grade Premium' 'Vacancy Rate Grade Premium'
#  'Total Vacancy' 'Vacancy Rate' 'Total Vacancy Grade A'
#  'Vacancy Rate Grade A' 'Total Vacancy Grade B' 'Vacancy Rate Grade B'
#  'Total Vacancy Grade C' 'Vacancy Rate Grade C' 'Total Vacancy Grade D'
#  'Vacancy Rate Grade D' 'Total Vacancy Secondary Grade'
#  'Vacancy Rate Secondary Grade' 'Total Vacancy Overall'
#  'Vacancy Rate Overall' 'Specialty Shops Vacant']
# * Different sources found (1): ['JLL']

# %%
_
# Out:
#              indicator_info__name    indicator_info__description source__id
# 0     Total Vacancy Grade Premium    Total Vacancy Grade Premium        JLL
# 1      Vacancy Rate Grade Premium     Vacancy Rate Grade Premium        JLL
# 2                   Total Vacancy                  Total Vacancy        JLL
# 3                    Vacancy Rate                   Vacancy Rate        JLL
# 4           Total Vacancy Grade A          Total Vacancy Grade A        JLL
# 5            Vacancy Rate Grade A           Vacancy Rate Grade A        JLL
# 6           Total Vacancy Grade B          Total Vacancy Grade B        JLL
# 7            Vacancy Rate Grade B           Vacancy Rate Grade B        JLL
# 8           Total Vacancy Grade C          Total Vacancy Grade C        JLL
# 9            Vacancy Rate Grade C           Vacancy Rate Grade C        JLL
# 10          Total Vacancy Grade D          Total Vacancy Grade D        JLL
# 11           Vacancy Rate Grade D           Vacancy Rate Grade D        JLL
# 12  Total Vacancy Secondary Grade  Total Vacancy Secondary Grade        JLL
# 13   Vacancy Rate Secondary Grade   Vacancy Rate Secondary Grade        JLL
# 14          Total Vacancy Overall          Total Vacancy Overall        JLL
# 15           Vacancy Rate Overall           Vacancy Rate Overall        JLL
# 78         Specialty Shops Vacant                                       JLL

# %%
_ = sources_that_contain_indicator('occ')
# Out:
# * Different indicators found (11): ['occupation rate' 'specialty occupancy cost' 'Dwelling occupancy rate'
#  'Occupied Stock Grade Premium' 'Occupied Stock' 'Occupied Stock Grade A'
#  'Occupied Stock Grade B' 'Occupied Stock Grade C'
#  'Occupied Stock Grade D' 'Occupied Stock Secondary Grade'
#  'Occupied Stock Overall']
# * Different sources found (5): ['GPT' 'ID_POPUL' 'STOCKLAND' 'JLL' 'VICINITY']

# %%
_
# Out:
#                indicator_info__name  \
# 0                   occupation rate
# 13         specialty occupancy cost
# 70          Dwelling occupancy rate
# 198        specialty occupancy cost
# 246    Occupied Stock Grade Premium
# 247                  Occupied Stock
# 248          Occupied Stock Grade A
# 249          Occupied Stock Grade B
# 250          Occupied Stock Grade C
# 251          Occupied Stock Grade D
# 252  Occupied Stock Secondary Grade
# 253          Occupied Stock Overall
# 285                 occupation rate
# 331        specialty occupancy cost
#
#                            indicator_info__description source__id
# 0                                      occupation rate        GPT
# 13   costs related to occupying a space in specialt...        GPT
# 70                    Percentage of dwelling occupancy   ID_POPUL
# 198  costs related to occupying a space in specialt...  STOCKLAND
# 246                       Occupied Stock Grade Premium        JLL
# 247                                     Occupied Stock        JLL
# 248                             Occupied Stock Grade A        JLL
# 249                             Occupied Stock Grade B        JLL
# 250                             Occupied Stock Grade C        JLL
# 251                             Occupied Stock Grade D        JLL
# 252                     Occupied Stock Secondary Grade        JLL
# 253                             Occupied Stock Overall        JLL
# 285                                    occupation rate   VICINITY
# 331  costs related to occupying a space in specialt...   VICINITY

# %% [markdown]
# ### Who has specialty data?

# %%
_ = sources_that_contain_indicator('specialty')
# Out:
# * Different indicators found (9): ['specialty occupancy cost' 'specialty sales' 'Prime Rents Specialty Rent'
#  'Prime Rents Average Specialty Rental Growth' 'Specialty Shops Vacant'
#  'Super-Prime Rents Average Specialty Rental Growth'
#  'Super-Prime Rents Specialty Rent' 'Specialty Rent'
#  'Average Specialty Rental Growth']
# * Different sources found (5): ['GPT' 'STOCKLAND' 'VICINITY' 'SCENTRE' 'JLL']

# %%
_
# Out:
#                                   indicator_info__name  \
# 0                             specialty occupancy cost
# 18                            specialty occupancy cost
# 66                            specialty occupancy cost
# 223                                    specialty sales
# 241                                    specialty sales
# 283                                    specialty sales
# 325                                    specialty sales
# 482                         Prime Rents Specialty Rent
# 492        Prime Rents Average Specialty Rental Growth
# 502                             Specialty Shops Vacant
# 558  Super-Prime Rents Average Specialty Rental Growth
# 568                   Super-Prime Rents Specialty Rent
# 578                                     Specialty Rent
# 618                    Average Specialty Rental Growth
#
#                            indicator_info__description source__id
# 0    costs related to occupying a space in specialt...        GPT
# 18   costs related to occupying a space in specialt...  STOCKLAND
# 66   costs related to occupying a space in specialt...   VICINITY
# 223                          sales in specialty retail        GPT
# 241                          sales in specialty retail  STOCKLAND
# 283                          sales in specialty retail    SCENTRE
# 325                          sales in specialty retail   VICINITY
# 482                                                           JLL
# 492                                                           JLL
# 502                                                           JLL
# 558                                                           JLL
# 568                                                           JLL
# 578                                                           JLL
# 618                                                           JLL

# %% [markdown]
# ### Who has cap_rate data  (also yield)?

# %%
_ = sources_that_contain_indicator('cap')
# Out:
# * Different indicators found (6): ['capitalisation rate' 'Capital Value' 'Capital Value Growth q-o-q'
#  'Capital Value Growth y-o-y' 'Capital Value Indicator Prime Grade'
#  'Capital Value Indicator']
# * Different sources found (5): ['GPT' 'STOCKLAND' 'JLL' 'SCENTRE' 'VICINITY']

# %%
_
# Out:
#           indicator_info__id                 indicator_info__name  \
# 0                   CAP_RATE                  capitalisation rate
# 50                  CAP_RATE                  capitalisation rate
# 158              CAPITAL_VAL                        Capital Value
# 159     CAPITAL_VAL_GRTH_QOQ           Capital Value Growth q-o-q
# 160     CAPITAL_VAL_GRTH_YOY           Capital Value Growth y-o-y
# 161    CAPITAL_VAL_IND_PRIME  Capital Value Indicator Prime Grade
# 178                 CAP_RATE                  capitalisation rate
# 221                 CAP_RATE                  capitalisation rate
# 380  Capital_Value_Indicator              Capital Value Indicator
#
#                            indicator_info__description source__id
# 0    net operating income of a property divided by ...        GPT
# 50   net operating income of a property divided by ...  STOCKLAND
# 158                                      Capital Value        JLL
# 159                         Capital Value Growth q-o-q        JLL
# 160                         Capital Value Growth y-o-y        JLL
# 161                Capital Value Indicator Prime Grade        JLL
# 178  net operating income of a property divided by ...    SCENTRE
# 221  net operating income of a property divided by ...   VICINITY
# 380                                                           JLL

# %%
_ = sources_that_contain_indicator('yield')
# Out:
# * Different indicators found (10): ['Equivalent Yield Upper Prime Grade' 'Equivalent Yield Lower Prime Grade'
#  'Equivalent Average Yield Prime Grade'
#  'Equivalent Yield Upper Secondary Grade'
#  'Equivalent Yield Lower Secondary Grade'
#  'Equivalent Average Yield Secondary Grade' 'Lower Yield'
#  'Mid-Point Yield' 'Upper Yield' 'Median Yield']
# * Different sources found (1): ['JLL']

# %%
_
# Out:
#                          indicator_info__name  \
# 0          Equivalent Yield Upper Prime Grade
# 5          Equivalent Yield Lower Prime Grade
# 10       Equivalent Average Yield Prime Grade
# 15     Equivalent Yield Upper Secondary Grade
# 20     Equivalent Yield Lower Secondary Grade
# 25   Equivalent Average Yield Secondary Grade
# 30                                Lower Yield
# 84                            Mid-Point Yield
# 116                               Upper Yield
# 170                              Median Yield
#
#                   indicator_info__description source__id
# 0          Equivalent Yield Upper Prime Grade        JLL
# 5          Equivalent Yield Lower Prime Grade        JLL
# 10       Equivalent Average Yield Prime Grade        JLL
# 15     Equivalent Yield Upper Secondary Grade        JLL
# 20     Equivalent Yield Lower Secondary Grade        JLL
# 25   Equivalent Average Yield Secondary Grade        JLL
# 30                                                   JLL
# 84                                                   JLL
# 116                                                  JLL
# 170                                                  JLL

# %% [markdown]
# ## Extracting the relevant data

# %%
get_stactuals(cursor=None, where={'indicator__source_id': 'JLL'}, columns=['value', 'date', 'indicator_id', 'indicator__source_id'], use_django_orm=True)
# Out:
#          indicator_id       date  value_change  error_code  st_processed  \
# 0                3947 1986-09-23           NaN         0.0         False
# 1                3947 1980-01-01           NaN         0.0         False
# 2                3947 1980-01-02           NaN         0.0         False
# 3                3947 1980-01-03           NaN         0.0         False
# 4                3947 1980-01-04           NaN         0.0         False
# ...               ...        ...           ...         ...           ...
# 1200907          9950 2013-10-23           NaN       128.0         False
# 1200908          9950 2013-10-24           NaN       128.0         False
# 1200909          9950 2013-10-25           NaN       128.0         False
# 1200910          9950 2013-10-26           NaN       128.0         False
# 1200911          9950 2013-10-27           NaN       128.0         False
#
#          af_processed folder_name                       update_date  \
# 0                True      Office  2019-12-15 14:05:39.648309+00:00
# 1                True      Office  2019-12-15 14:05:39.648309+00:00
# 2                True      Office  2019-12-15 14:05:39.648309+00:00
# 3                True      Office  2019-12-15 14:05:39.648309+00:00
# 4                True      Office  2019-12-15 14:05:39.648309+00:00
# ...               ...         ...                               ...
# 1200907          True      Retail  2020-01-03 09:59:16.021078+00:00
# 1200908          True      Retail  2020-01-03 09:59:16.021078+00:00
# 1200909          True      Retail  2020-01-03 09:59:16.021078+00:00
# 1200910          True      Retail  2020-01-03 09:59:16.021078+00:00
# 1200911          True      Retail  2020-01-03 09:59:16.021078+00:00
#
#                value indicator__source_id
# 0        4875.652174                  JLL
# 1        1590.000000                  JLL
# 2        1592.197802                  JLL
# 3        1594.395604                  JLL
# 4        1596.593407                  JLL
# ...              ...                  ...
# 1200907     0.075000                  JLL
# 1200908     0.075000                  JLL
# 1200909     0.075000                  JLL
# 1200910     0.075000                  JLL
# 1200911     0.075000                  JLL
#
# [1200912 rows x 10 columns]

# %%
get_actuals??

# %% [markdown]
# Vicinity, stockland y GPT tienen también datos de housing y offices (aparte de retail), solo nos interesa retail. Mirar la variable folder_name.

# %% [markdown]
# llamar get_actuals para sacar las cosas de jll.

# %% [markdown]
# Segmentar por regional/sub_regional/cvd.
