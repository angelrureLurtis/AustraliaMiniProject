# %% [markdown]
# # Exploring indicators

# %% [markdown]
# This notebook explores the existence of Yi Peng's indicators in ABS and id_population sources.
# Then we will try to segment by type and see if we can extrapolate the data.

# %% [markdown]
# ## Function definitions and django manage

# %%
import os

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

import os
import pandas as pd

os.chdir('../../deciml_django/')

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'deciml.settings')

from deciml.apps.db.models import *
from deciml.apps.common.utils import get_actuals

# %%
def sources_that_contain_indicator(indicator):
    """
    indicator should be the minimum you want to find. indicator='Hoc' would
    match both Hockey and ChOcOlate.
    """
    df = pd.DataFrame(Indicator.objects.filter(indicator_info__name__icontains=indicator)\
                               .values('indicator_info__id',
                                       'indicator_info__name', 
                                       'indicator_info__description',
                                       'source__id'))
    
    df = df.drop_duplicates()
    diff_sources = df.source__id.unique()
    diff_ind = df.indicator_info__name.unique()
    
    print('* Different indicators found ({ndi}): {di}'.format(ndi=len(diff_ind), di=diff_ind))
    print('* Different sources found ({nds}): {ds}'.format(nds=len(diff_sources), ds=diff_sources))
    return df

# %%
def indicators_from_source(source):
    df = pd.DataFrame(Indicator.objects.filter(source__id=source)\
                               .distinct('indicator_info__name')\
                               .values('indicator_info__name', 
                                       'indicator_info__description'))
    return df

# %%
def values_by_indicator_and_source(source, indicator):

    df = pd.DataFrame(

           Actual.objects.filter(indicator__source__id=source,
                                 indicator__indicator_info__name=indicator)\
                 .values('date', 'value', 'indicator__location__name')
    )
    
    return df

# %% [markdown]
# #### Target indicators

# %% [markdown]
# - [x] state population (ID_POPUL:Population, ABS:Population)
#     * Poor time depth
# - [x] city population (ID_POPUL:Population --> Description is wrong)
# - [x] GDP (ABS:Gross domestic product)
#     * Whole state
# - [x] household income (ABS:Gross Disposable Income)
#     * Whole state
# - [ ] household indebtedness

# %% [markdown]
# #### Extra indicators

# %% [markdown]
# - [X] Unemployment Tate (ABS:unemployment rate)

# %% [markdown]
# ## Exploring indicators and sources

# %% [markdown]
# We want to check if Yi Peng's indicators are available in several sources. Then we will check which sources have data about the vacancy/occupation, the cap_rate/yield or the specialty sales.

# %% [markdown]
# ### Indicators from ID_POPUL and ABS

# %%
indicators_from_source('ID_POPUL')
# Out:
#            indicator_info__description                 indicator_info__name
# 0         Average people per household               Average household size
# 1     Percentage of dwelling occupancy              Dwelling occupancy rate
# 2                  Number of dwellings                            Dwellings
# 3                 Number of households                           Households
# 4  Number of persons living in a state                           Population
# 5  Population in non private dwellings  Population in non private dwellings

# %%
indicators_from_source('ABS')
# Out:
#                           indicator_info__description  \
# 0    total value of approved service sector buildings
# 1            gross value of service sector businesses
# 2   total value of income by service sector busine...
# 3          value lending to service sector businesses
# 4    Female to male ratio of people living in a state
# 5                   Household gross disposable income
# 6                              Gross domestic product
# 7                                 Gross State Product
# 8   Average number of persons that live per household
# 9   Number of persons moving into/out of a country...
# 10                          New inward migration rate
# 11  Number of Dwelling Units Approved in New Resid...
# 12  Value of Dwelling Units Approved in New Reside...
# 13                Number of persons living in a state
# 14  Number of persons born outside of a country pe...
# 15  Number of persons per squared unit living in a...
# 22    2013-01-01                    Australia  5.384528
# 23    2012-12-01                    Australia  5.431350
# 24    2012-11-01                    Australia  5.257020
# 25    2012-10-01                    Australia  5.417596
# 26    2012-09-01                    Australia  5.491368
# 27    2012-08-01                    Australia  5.144665
# 28    2012-07-01                    Australia  5.173407
# 29    2012-06-01                    Australia  5.165234
# ...          ...                          ...       ...
# 3435  1982-01-01  Western Australia Australia  7.043967
# 3436  1981-12-01  Western Australia Australia  6.833227
# 3437  1981-10-01  Western Australia Australia  6.141391
# 3438  1981-09-01  Western Australia Australia  6.559059
# 3439  1981-08-01  Western Australia Australia  6.215809
# 3440  1981-07-01  Western Australia Australia  5.602178
# 3441  1981-06-01  Western Australia Australia  5.639616
# 3442  1981-05-01  Western Australia Australia  5.858467
# 3443  1981-04-01  Western Australia Australia  5.452414
# 3444  1981-03-01  Western Australia Australia  5.959664
# 3445  1981-02-01  Western Australia Australia  5.658421
# 3446  1981-01-01  Western Australia Australia  5.861811
# 3447  1980-12-01  Western Australia Australia  6.166330
# 3448  1980-11-01  Western Australia Australia  5.636839
# 3449  1980-10-01  Western Australia Australia  6.268534
# 3450  1980-09-01  Western Australia Australia  6.026737
# 3451  1980-08-01  Western Australia Australia  6.244397
# 3452  1980-07-01  Western Australia Australia  6.103461
# 3453  1980-06-01  Western Australia Australia  6.388643
# 3454  1980-05-01  Western Australia Australia  6.537888
# 3455  1980-04-01  Western Australia Australia  6.404880
# 3456  1980-03-01  Western Australia Australia  6.441898
# 3457  1980-02-01  Western Australia Australia  7.100746
# 3458  1980-01-01  Western Australia Australia  7.091582
# 3459  1979-11-01  Western Australia Australia  7.271347
# 3460  1979-10-01  Western Australia Australia  7.868502
# 3461  1979-09-01  Western Australia Australia  7.216421
# 3462  1979-08-01  Western Australia Australia  7.297816
# 3463  1979-07-01  Western Australia Australia  7.573855
# 3464  1979-06-01  Western Australia Australia  6.882589
#
# [3465 rows x 3 columns]

# %%
values_by_indicator_and_source('ABS', 'unemployment rate').indicator__location__name.unique()
# Out:
# array(['Australia', 'New South Wales Australia', 'Queensland Australia',
#        'South Australia Australia', 'Tasmania Australia',
#        'Victoria Australia', 'Western Australia Australia'], dtype=object)

# %% [markdown]
# ### Who has vacancy data (Or occupation)?

# %%
_ = sources_that_contain_indicator('vac')
# Out:
# * Different indicators found (18): ['Total Vacancy Grade Premium' 'Vacancy Rate Grade Premium'
#  'Total Vacancy' 'Vacancy Rate' 'Total Vacancy Grade A'
#  'Vacancy Rate Grade A' 'Total Vacancy Grade B' 'Vacancy Rate Grade B'
#  'Total Vacancy Grade C' 'Vacancy Rate Grade C' 'Total Vacancy Grade D'
#  'Vacancy Rate Grade D' 'Total Vacancy Secondary Grade'
#  'Vacancy Rate Secondary Grade' 'Total Vacancy Overall'
#  'Vacancy Rate Overall' 'Specialty Shops Vacant' 'VACANCY']
# * Different sources found (2): ['JLL' 'STOCKLAND']

# %%
_
# Out:
#        indicator_info__description       indicator_info__id  \
# 0      Total Vacancy Grade Premium        TOTAL_VAC_PREMIUM
# 1       Vacancy Rate Grade Premium   TOTAL_VAC_RATE_PREMIUM
# 2                    Total Vacancy            TOTAL_VACANCY
# 3                     Vacancy Rate             VACANCY_RATE
# 4            Total Vacancy Grade A    TOTAL_VACANCY_A_GRADE
# 5             Vacancy Rate Grade A     VACANCY_RATE_A_GRADE
# 6            Total Vacancy Grade B    TOTAL_VACANCY_B_GRADE
# 7             Vacancy Rate Grade B     VACANCY_RATE_B_GRADE
# 8            Total Vacancy Grade C    TOTAL_VACANCY_C_GRADE
# 9             Vacancy Rate Grade C     VACANCY_RATE_C_GRADE
# 10           Total Vacancy Grade D    TOTAL_VACANCY_D_GRADE
# 11            Vacancy Rate Grade D     VACANCY_RATE_D_GRADE
# 12   Total Vacancy Secondary Grade  TOTAL_VACANCY_SEC_GRADE
# 13    Vacancy Rate Secondary Grade   VACANCY_RATE_SEC_GRADE
# 14           Total Vacancy Overall    TOTAL_VACANCY_OVERALL
# 15            Vacancy Rate Overall     VACANCY_RATE_OVERALL
# 78                                   Specialty_Shops_Vacant
# 106                                                 VACANCY
#
#               indicator_info__name source__id
# 0      Total Vacancy Grade Premium        JLL
# 1       Vacancy Rate Grade Premium        JLL
# 2                    Total Vacancy        JLL
# 3                     Vacancy Rate        JLL
# 4            Total Vacancy Grade A        JLL
# 5             Vacancy Rate Grade A        JLL
# 6            Total Vacancy Grade B        JLL
# 7             Vacancy Rate Grade B        JLL
# 8            Total Vacancy Grade C        JLL
# 9             Vacancy Rate Grade C        JLL
# 10           Total Vacancy Grade D        JLL
# 11            Vacancy Rate Grade D        JLL
# 12   Total Vacancy Secondary Grade        JLL
# 13    Vacancy Rate Secondary Grade        JLL
# 14           Total Vacancy Overall        JLL
# 15            Vacancy Rate Overall        JLL
# 78          Specialty Shops Vacant        JLL
# 106                        VACANCY  STOCKLAND

# %%
_ = sources_that_contain_indicator('occ')
# Out:
# * Different indicators found (11): ['occupation rate' 'specialty occupancy cost' 'Dwelling occupancy rate'
#  'Occupied Stock Grade Premium' 'Occupied Stock' 'Occupied Stock Grade A'
#  'Occupied Stock Grade B' 'Occupied Stock Grade C'
#  'Occupied Stock Grade D' 'Occupied Stock Secondary Grade'
#  'Occupied Stock Overall']
# * Different sources found (5): ['GPT' 'ID_POPUL' 'STOCKLAND' 'VICINITY' 'JLL']

# %%
_
# Out:
#                            indicator_info__description  \
# 0                                      occupation rate
# 13   costs related to occupying a space in specialt...
# 70                    Percentage of dwelling occupancy
# 198  costs related to occupying a space in specialt...
# 246                                    occupation rate
# 292  costs related to occupying a space in specialt...
# 573                       Occupied Stock Grade Premium
# 574                                     Occupied Stock
# 575                             Occupied Stock Grade A
# 576                             Occupied Stock Grade B
# 577                             Occupied Stock Grade C
# 578                             Occupied Stock Grade D
# 579                     Occupied Stock Secondary Grade
# 580                             Occupied Stock Overall
#
#           indicator_info__id            indicator_info__name source__id
# 0                   OCC_RATE                 occupation rate        GPT
# 13        SPECIALTY_OCC_COST        specialty occupancy cost        GPT
# 70         DWELLING_OCC_RATE         Dwelling occupancy rate   ID_POPUL
# 198       SPECIALTY_OCC_COST        specialty occupancy cost  STOCKLAND
# 246                 OCC_RATE                 occupation rate   VICINITY
# 292       SPECIALTY_OCC_COST        specialty occupancy cost   VICINITY
# 573    OCCUPIED_STCK_PREMIUM    Occupied Stock Grade Premium        JLL
# 574           OCCUPIED_STOCK                  Occupied Stock        JLL
# 575    OCCUPIED_STCK_A_GRADE          Occupied Stock Grade A        JLL
# 576    OCCUPIED_STCK_B_GRADE          Occupied Stock Grade B        JLL
# 577    OCCUPIED_STCK_C_GRADE          Occupied Stock Grade C        JLL
# 578    OCCUPIED_STCK_D_GRADE          Occupied Stock Grade D        JLL
# 579  OCCUPIED_STCK_SEC_GRADE  Occupied Stock Secondary Grade        JLL
# 580    OCCUPIED_STCK_OVERALL          Occupied Stock Overall        JLL

# %% [markdown]
# ### Who has specialty data?

# %%
_ = sources_that_contain_indicator('specialty')
# Out:
# * Different indicators found (9): ['specialty occupancy cost' 'specialty sales' 'Prime Rents Specialty Rent'
#  'Prime Rents Average Specialty Rental Growth' 'Specialty Shops Vacant'
#  'Super-Prime Rents Average Specialty Rental Growth'
#  'Super-Prime Rents Specialty Rent' 'Specialty Rent'
#  'Average Specialty Rental Growth']
# * Different sources found (5): ['GPT' 'STOCKLAND' 'VICINITY' 'SCENTRE' 'JLL']

# %%
_
# Out:
#                            indicator_info__description  \
# 0    costs related to occupying a space in specialt...
# 18   costs related to occupying a space in specialt...
# 66   costs related to occupying a space in specialt...
# 228                          sales in specialty retail
# 246                          sales in specialty retail
# 288                          sales in specialty retail
# 335                          sales in specialty retail
# 492
# 497
# 502
# 530
# 535
# 540
# 560
#
#                           indicator_info__id  \
# 0                         SPECIALTY_OCC_COST
# 18                        SPECIALTY_OCC_COST
# 66                        SPECIALTY_OCC_COST
# 228                          SPECIALTY_SALES
# 246                          SPECIALTY_SALES
# 288                          SPECIALTY_SALES
# 335                          SPECIALTY_SALES
# 492               Prime_Rents_Specialty_Rent
# 497  Prime_Rents_Average_Specialty_Rental_Gr
# 502                   Specialty_Shops_Vacant
# 530  Super-Prime_Rents_Average_Specialty_Ren
# 535         Super-Prime_Rents_Specialty_Rent
# 540                           Specialty_Rent
# 560          Average_Specialty_Rental_Growth
#
#                                   indicator_info__name source__id
# 0                             specialty occupancy cost        GPT
# 18                            specialty occupancy cost  STOCKLAND
# 66                            specialty occupancy cost   VICINITY
# 228                                    specialty sales        GPT
# 246                                    specialty sales  STOCKLAND
# 288                                    specialty sales   VICINITY
# 335                                    specialty sales    SCENTRE
# 492                         Prime Rents Specialty Rent        JLL
# 497        Prime Rents Average Specialty Rental Growth        JLL
# 502                             Specialty Shops Vacant        JLL
# 530  Super-Prime Rents Average Specialty Rental Growth        JLL
# 535                   Super-Prime Rents Specialty Rent        JLL
# 540                                     Specialty Rent        JLL
# 560                    Average Specialty Rental Growth        JLL

# %% [markdown]
# ### Who has cap_rate data  (also yield)?

# %%
_ = sources_that_contain_indicator('cap')
# Out:
# * Different indicators found (6): ['capitalisation rate' 'Capital Value' 'Capital Value Growth q-o-q'
#  'Capital Value Growth y-o-y' 'Capital Value Indicator Prime Grade'
#  'Capital Value Indicator']
# * Different sources found (5): ['GPT' 'STOCKLAND' 'VICINITY' 'SCENTRE' 'JLL']

# %%
_
# Out:
#                            indicator_info__description  \
# 0    net operating income of a property divided by ...
# 50   net operating income of a property divided by ...
# 158  net operating income of a property divided by ...
# 221  net operating income of a property divided by ...
# 366                                      Capital Value
# 367                         Capital Value Growth q-o-q
# 368                         Capital Value Growth y-o-y
# 369                Capital Value Indicator Prime Grade
# 386
#
#           indicator_info__id                 indicator_info__name source__id
# 0                   CAP_RATE                  capitalisation rate        GPT
# 50                  CAP_RATE                  capitalisation rate  STOCKLAND
# 158                 CAP_RATE                  capitalisation rate   VICINITY
# 221                 CAP_RATE                  capitalisation rate    SCENTRE
# 366              CAPITAL_VAL                        Capital Value        JLL
# 367     CAPITAL_VAL_GRTH_QOQ           Capital Value Growth q-o-q        JLL
# 368     CAPITAL_VAL_GRTH_YOY           Capital Value Growth y-o-y        JLL
# 369    CAPITAL_VAL_IND_PRIME  Capital Value Indicator Prime Grade        JLL
# 386  Capital_Value_Indicator              Capital Value Indicator        JLL

# %%
_ = sources_that_contain_indicator('yield')
# Out:
# * Different indicators found (10): ['Equivalent Yield Upper Prime Grade' 'Equivalent Yield Lower Prime Grade'
#  'Equivalent Average Yield Prime Grade'
#  'Equivalent Yield Upper Secondary Grade'
#  'Equivalent Yield Lower Secondary Grade'
#  'Equivalent Average Yield Secondary Grade' 'Lower Yield'
#  'Mid-Point Yield' 'Upper Yield' 'Median Yield']
# * Different sources found (1): ['JLL']

# %%
_
# Out:
#                   indicator_info__description    indicator_info__id  \
# 0          Equivalent Yield Upper Prime Grade  EQ_YIELD_UPPER_PRIME
# 5          Equivalent Yield Lower Prime Grade  EQ_YIELD_LOWER_PRIME
# 10       Equivalent Average Yield Prime Grade    EQ_AVG_YIELD_PRIME
# 15     Equivalent Yield Upper Secondary Grade    EQ_YIELD_UPPER_SEC
# 20     Equivalent Yield Lower Secondary Grade    EQ_YIELD_LOWER_SEC
# 25   Equivalent Average Yield Secondary Grade      EQ_AVG_YIELD_SEC
# 30                                                      Lower_Yield
# 57                                                  Mid-Point_Yield
# 73                                                      Upper_Yield
# 100                                                    Median_Yield
#
#                          indicator_info__name source__id
# 0          Equivalent Yield Upper Prime Grade        JLL
# 5          Equivalent Yield Lower Prime Grade        JLL
# 10       Equivalent Average Yield Prime Grade        JLL
# 15     Equivalent Yield Upper Secondary Grade        JLL
# 20     Equivalent Yield Lower Secondary Grade        JLL
# 25   Equivalent Average Yield Secondary Grade        JLL
# 30                                Lower Yield        JLL
# 57                            Mid-Point Yield        JLL
# 73                                Upper Yield        JLL
# 100                              Median Yield        JLL

# %% [markdown]
# ## Extracting the relevant data

# %% [markdown]
# Vicinity, stockland y GPT tienen también datos de housing y offices (aparte de retail), solo nos interesa retail. Mirar la variable folder_name.

# %% [markdown]
# llamar get_actuals para sacar las cosas de jll.

# %% [markdown]
# Segmentar por regional/sub_regional/cvd.
